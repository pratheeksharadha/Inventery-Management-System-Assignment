# %%
data={ 1001: {'Product_name': 'Maggie','Price': 20,'Quantity': 200,'Category':'Noodles','Manufacturing_date': '12-02-21','Expiry_date': '12-05-21'},
       1002: {'Product_name': 'Top Ramen','Price': 70,'Quantity': 300,'Category':'Noodles','Manufacturing_date': '14-03-21','Expiry_date': '14-06-21'},
       1003: {'Product_name': 'Soorya Noodles','Price':100,'Quantity':350,'Category':'Noodles','Manufacturing_date':'11-02-21','Expiry_date' : '11-05-21'},
       1004: {'Product_name': 'Anil Noodles','Price': 20,'Quantity': 300,'Category':'Noodles','Manufacturing_date': '04-02-21','Expiry_date': '12-05-21'},
       1005: {'Product_name': 'Soupy Noodles','Price': 140,'Quantity': 350,'Category':'Noodles','Manufacturing_date': '10-02-21','Expiry_date': '10-05-21'},
       1006: {'Product_name': 'Freedom oil','Price': 120,'Quantity': 300,'Category':'Oil','Manufacturing_date': '12-02-21','Expiry_date': '12-05-21'},
       1007: {'Product_name': 'Fortune oil','Price': 150,'Quantity': 400,'Category':'Oil','Manufacturing_date': '10-01-21','Expiry_date': '10-04-21'},
       1008: {'Product_name': 'Ashirvad atta','Price': 70,'Quantity': 300,'Category':'Atta','Manufacturing_date': '01-02-21','Expiry_date': '01-05-21'},
       1009: {'Product_name': 'Annapurna atta','Price': 120,'Quantity': 250,'Category':'Atta','Manufacturing_date': '12-05-21','Expiry_date': '12-08-21'},
       1010: {'Product_name': 'IndiaGate rice','Price': 120,'Quantity': 200,'Category':'Rice','Manufacturing_date': '01-02-21','Expiry_date': '01-05-21'},
       1011: {'Product_name': 'TajMahal rice','Price': 140,'Quantity': 300,'Category':'Rice','Manufacturing_date': '12-03-21','Expiry_date': '12-06-21'},
       1012: {'Product_name': 'Anand rice(25kg)','Price': 900,'Quantity': 300,'Category':'Rice','Manufacturing_date': '10-05-21','Expiry_date': '10-08-21'},
       1013: {'Product_name': 'Knandevan','Price': 120,'Quantity': 200,'Category':'Tea powder','Manufacturing_date': '03-02-21','Expiry_date': '03-05-21'},
       1014: {'Product_name': 'Devegeree','Price': 80,'Quantity': 200,'Category':'Tea powder','Manufacturing_date': '05-03-21','Expiry_date': '05-06-21'},
       1015: {'Product_name': 'Nescafe','Price': 150,'Quantity': 200,'Category':'Coffee powder','Manufacturing_date': '12-04-21','Expiry_date': '12-07-21'},
       1016: {'Product_name': 'Nescafe Gold','Price': 200,'Quantity': 200,'Category':'Coffee powder','Manufacturing_date': '10-02-21','Expiry_date': '10-05-21'},
       1017: {'Product_name': 'Goodday','Price': 30,'Quantity': 200,'Category':'Biscuit','Manufacturing_date': '09-03-21','Expiry_date': '09-06-21'},
       1018: {'Product_name': 'Parle-g','Price': 20,'Quantity': 200,'Category':'Biscuit','Manufacturing_date': '12-08-21','Expiry_date': '12-11-21'},
       1019: {'Product_name': 'Vita-Marie-Gold','Price': 24,'Quantity': 200,'Category':'Biscuit','Manufacturing_date': '10-09-21','Expiry_date': '10-12-21'},
       1020: {'Product_name': 'Oreo','Price': 50,'Quantity': 200,'Category':'Biscuit','Manufacturing_date': '05-02-21','Expiry_date': '05-05-21'},
       1021: {'Product_name': 'Crack-Jack','Price': 30,'Quantity': 200,'Category':'Biscuit','Manufacturing_date': '15-04-21','Expiry_date': '15-07-21'},
       1022: {'Product_name': 'Bingo','Price': 20,'Quantity': 200,'Category':'Snacks','Manufacturing_date': '12-05-21','Expiry_date': '12-08-21'},
       1023: {'Product_name': 'Kurkure','Price': 20,'Quantity': 200,'Category':'Snacks','Manufacturing_date': '12-06-21','Expiry_date': '12-09-21'},
       1024: {'Product_name': 'Lays','Price': 20,'Quantity': 200,'Category':'Snacks','Manufacturing_date': '10-05-21','Expiry_date': '10-08-21'},
       1025: {'Product_name': '5-Star','Price': 30,'Quantity': 200,'Category':'Chocolate','Manufacturing_date': '01-02-21','Expiry_date': '01-05-21'},
       1026: {'Product_name': 'Milky Bar','Price': 30,'Quantity': 200,'Category':'Chocolate','Manufacturing_date': '03-03-21','Expiry_date': '03-06-21'},
       1027: {'Product_name': 'Bounty','Price': 40,'Quantity': 200,'Category':'Chocolate','Manufacturing_date': '12-02-21','Expiry_date': '12-05-21'},
       1028: {'Product_name': 'Galaxy','Price': 50,'Quantity': 200,'Category':'Chocolate','Manufacturing_date': '10-05-21','Expiry_date': '10-08-21'},
       1029: {'Product_name': 'Sneakers','Price': 30,'Quantity': 200,'Category':'Chocolate','Manufacturing_date': '12-02-21','Expiry_date': '12-04-21'},
       1030: {'Product_name': 'Diary Milk-Silk','Price': 50,'Quantity': 200,'Category':'Chocolate','Manufacturing_date': '12-02-21','Expiry_date': '12-03-21'},
       1031: {'Product_name': 'Kinder-Joy','Price': 25,'Quantity': 200,'Category':'Chocolate','Manufacturing_date': '12-04-21','Expiry_date': '12-05-21'},
       1032: {'Product_name': 'Sprite','Price': 40,'Quantity': 200,'Category':'Drinks','Manufacturing_date': '12-05-21','Expiry_date': '12-06-21'},
       1033: {'Product_name': 'Mazza','Price': 40,'Quantity': 200,'Category':'Drinks','Manufacturing_date': '10-06-21','Expiry_date': '10-07-21'},
       1034: {'Product_name': 'Coco cola','Price': 50,'Quantity': 200,'Category':'Drinks','Manufacturing_date': '12-08-21','Expiry_date': '12-09-21'},
       1035: {'Product_name': 'Pepsi','Price': 40,'Quantity': 200,'Category':'Drinks','Manufacturing_date': '12-02-21','Expiry_date': '12-03-21'},
       1036: {'Product_name': 'Mirinda','Price': 40,'Quantity': 200,'Category':'Drinks','Manufacturing_date': '03-02-21','Expiry_date': '12-04-21'},
       1037: {'Product_name': 'Vanila icecream','Price': 30,'Quantity': 200,'Category':'Icecream','Manufacturing_date': '12-06-21','Expiry_date': '12-07-21'},
       1038: {'Product_name': 'Chocolate icecream','Price': 40,'Quantity': 200,'Category':'Icecream','Manufacturing_date': '12-08-21','Expiry_date': '12-09-21'},
       1039: {'Product_name': 'Strawberry icecream','Price': 30,'Quantity': 200,'Category':'Icecream','Manufacturing_date': '12-10-21','Expiry_date': '12-11-21'},
       1040: {'Product_name': 'chocobar','Price': 20,'Quantity': 200,'Category':'Icecream','Manufacturing_date': '12-02-21','Expiry_date': '12-03-21'}}

# %%
data
# Out:
# {1001: {'Product_name': 'Maggie',
#   'Price': 20,
#   'Quantity': 200,
#   'Category': 'Noodles',
#   'Manufacturing_date': '12-02-21',
#   'Expiry_date': '12-05-21'},
#  1002: {'Product_name': 'Top Ramen',
#   'Price': 70,
#   'Quantity': 300,
#   'Category': 'Noodles',
#   'Manufacturing_date': '14-03-21',
#   'Expiry_date': '14-06-21'},
#  1003: {'Product_name': 'Soorya Noodles',
#   'Price': 100,
#   'Quantity': 350,
#   'Category': 'Noodles',
#   'Manufacturing_date': '11-02-21',
#   'Expiry_date': '11-05-21'},
#  1004: {'Product_name': 'Anil Noodles',
#   'Price': 20,
#   'Quantity': 300,
#   'Category': 'Noodles',
#   'Manufacturing_date': '04-02-21',
#   'Expiry_date': '12-05-21'},
#  1005: {'Product_name': 'Soupy Noodles',
#   'Price': 140,
#   'Quantity': 350,
#   'Category': 'Noodles',
#   'Manufacturing_date': '10-02-21',
#   'Expiry_date': '10-05-21'},
#  1006: {'Product_name': 'Freedom oil',
#   'Price': 120,
#   'Quantity': 300,
#   'Category': 'Oil',
# ...

# %%
import json

# %%
products_data=json.dumps(data)
products_data
# Out:
# '{"1001": {"Product_name": "Maggie", "Price": 20, "Quantity": 200, "Category": "Noodles", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1002": {"Product_name": "Top Ramen", "Price": 70, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "14-03-21", "Expiry_date": "14-06-21"}, "1003": {"Product_name": "Soorya Noodles", "Price": 100, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "11-02-21", "Expiry_date": "11-05-21"}, "1004": {"Product_name": "Anil Noodles", "Price": 20, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "04-02-21", "Expiry_date": "12-05-21"}, "1005": {"Product_name": "Soupy Noodles", "Price": 140, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "10-02-21", "Expiry_date": "10-05-21"}, "1006": {"Product_name": "Freedom oil", "Price": 120, "Quantity": 300, "Category": "Oil", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1007": {"Product_name": "Fortune oil", "Price": 150, "Quantity": 40
# ...

# %%
fd=open("recorded_data.json","w")
fd.write(products_data)
fd.close()

# %%
fd=open("recorded_data.json","r")
text=fd.read()
fd.close()

# %%
text
# Out:
# '{"1001": {"Product_name": "Maggie", "Price": 20, "Quantity": 200, "Category": "Noodles", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1002": {"Product_name": "Top Ramen", "Price": 70, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "14-03-21", "Expiry_date": "14-06-21"}, "1003": {"Product_name": "Soorya Noodles", "Price": 100, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "11-02-21", "Expiry_date": "11-05-21"}, "1004": {"Product_name": "Anil Noodles", "Price": 20, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "04-02-21", "Expiry_date": "12-05-21"}, "1005": {"Product_name": "Soupy Noodles", "Price": 140, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "10-02-21", "Expiry_date": "10-05-21"}, "1006": {"Product_name": "Freedom oil", "Price": 120, "Quantity": 300, "Category": "Oil", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1007": {"Product_name": "Fortune oil", "Price": 150, "Quantity": 40
# ...

# %%
record=json.loads(text)
record
# Out:
# {'1001': {'Product_name': 'Maggie',
#   'Price': 20,
#   'Quantity': 200,
#   'Category': 'Noodles',
#   'Manufacturing_date': '12-02-21',
#   'Expiry_date': '12-05-21'},
#  '1002': {'Product_name': 'Top Ramen',
#   'Price': 70,
#   'Quantity': 300,
#   'Category': 'Noodles',
#   'Manufacturing_date': '14-03-21',
#   'Expiry_date': '14-06-21'},
#  '1003': {'Product_name': 'Soorya Noodles',
#   'Price': 100,
#   'Quantity': 350,
#   'Category': 'Noodles',
#   'Manufacturing_date': '11-02-21',
#   'Expiry_date': '11-05-21'},
#  '1004': {'Product_name': 'Anil Noodles',
#   'Price': 20,
#   'Quantity': 300,
#   'Category': 'Noodles',
#   'Manufacturing_date': '04-02-21',
#   'Expiry_date': '12-05-21'},
#  '1005': {'Product_name': 'Soupy Noodles',
#   'Price': 140,
#   'Quantity': 350,
#   'Category': 'Noodles',
#   'Manufacturing_date': '10-02-21',
#   'Expiry_date': '10-05-21'},
#  '1006': {'Product_name': 'Freedom oil',
#   'Price': 120,
#   'Quantity': 300,
#   'Category': 'Oil',
# ...

# %%
import time
id="1"

# %%
print("WELCOME TO PRATHEEKSHA GENERAL STORE")
choice=int(input("1.Do you want to purchase products? then enter 1\n"))
if(choice==1):
    print("Our store has:")
    for i in record.keys():
        print(record[i]["Product_name"])
    print("The items available are:")
    items={}
    sales={}
    for i in  record.keys():
        print("Product_no:\t"+str(i)+"\tProducts:"+str(record[i]["Product_name"]) +"\t\tPrice:"+str(record[i]["Price"])+"\t\tAvailability:"+str(record[i]["Quantity"]))
    print("enter Customer details")
    customer_name=input("enter your name:")
    customer_address=input("enter your address:")
    items_no=int(input("How many items do you want to purchase:"))
    price=0
    for i in range(items_no):
        product_purchased=input("Enter the product brand you want to purchase:")
        quantity_purchased=int(input("Enter the quantity of product you want to purchase:"))
        items[product_purchased]=quantity_purchased
        for i in record.keys():
            if(record[i]["Product_name"]==product_purchased):
                if(record[i]["Quantity"]>=quantity_purchased):
                    print("Your item's stock is available")
                    print("cost is:Rs."+str(quantity_purchased*(record[i]["Price"])))
                    total_price=quantity_purchased*record[i]["Price"]
                    price+=total_price
                else:
                    print("Your item's stock is not available")
    print("Your bill is Rs. "+str(price)+"  Please pay the bill\n")
    payment_status=input("Please enter yes if payment is completed\n")
    if payment_status=="yes":
        print("-----------------------------------------------------")
        print("Your payement is completed")
        print("The product you purchased are:")
        for i in items.keys():
            print("Product:"+str(i)+"\tQuantity:"+str(items[i]))     
        print("Payed ammount is:"+str(price))
        print("-----------------------------------------------------")
        for i in items.keys():
            for j in record.keys():
                if(record[j]["Product_name"]==i):
                    x=record[j]["Quantity"]
                    record[j]["Quantity"]=x-items[i]
        for i in items.keys():
            for j in record.keys():
                if(i==record[j]["Product_name"]):
                    sales[id]={"customer_name":customer_name, "customer_address":customer_address, "Details":items,"transaction_time":time.ctime()}
                    id=str(int(id)+1)
        sales_data=json.dumps(sales)
        sales_data
        fs=open("sales_data.json","a")
        fs.write(sales_data)
        fs.close()
#if(choice==2):
 #   n=int(input("enter number of product details you want to store:"))
  #  for i in range(n):
   #     product_id=input("enter the product id:")
    #    product_name=input("enter the product name:")
     #   product_price=int(input("enter the product price:"))
      #  product_quantity=int(input("enter the product quantity:"))
       # product_category=input("enter the product category:")
        #product_manu_date=input("enter the product manufacture date:")
       # product_exp_date=input("enter the product expiryy date:")
        #data=record
        #if(product_id in data):
         #   record[product_id]={'Product_name': product_name,'Price': product_price,'Quantity': data[product_id]['Quantity']+product_quantity,'Category':product_category,'Manufacturing_date': product_manu_date , 'Expiry_date':  product_exp_date}
        #else:
         #   record[product_id]={'Product_name': product_name,'Price': product_price,'Quantity': product_quantity,'Category':product_category,'Manufacturing_date': product_manu_date , 'Expiry_date':  product_exp_date}
# Out:
# WELCOME TO PRATHEEKSHA GENERAL STORE
# 1.Do you want to purchase products? then enter 1
# 1
# Our store has:
# Maggie
# Top Ramen
# Soorya Noodles
# Anil Noodles
# Soupy Noodles
# Freedom oil
# Fortune oil
# Ashirvad atta
# Annapurna atta
# IndiaGate rice
# TajMahal rice
# Anand rice(25kg)
# Knandevan
# Devegeree
# Nescafe
# Nescafe Gold
# Goodday
# Parle-g
# Vita-Marie-Gold
# Oreo
# Crack-Jack
# Bingo
# Kurkure
# Lays
# 5-Star
# Milky Bar
# Bounty
# Galaxy
# Sneakers
# Diary Milk-Silk
# Kinder-Joy
# Sprite
# Mazza
# Coco cola
# Pepsi
# Mirinda
# Vanila icecream
# Chocolate icecream
# Strawberry icecream
# chocobar
# The items available are:
# Product_no:	1001	Products:Maggie		Price:20		Availability:200
# Product_no:	1002	Products:Top Ramen		Price:70		Availability:300
# Product_no:	1003	Products:Soorya Noodles		Price:100		Availability:350
# Product_no:	1004	Products:Anil Noodles		Price:20		Availability:300
# Product_no:	1005	Products:Soupy Noodles		Price:140		Availability:350
# ...

# %%
#add products to the store

# %%
#this code is to add product to a store.
n=int(input("enter number of product details you want to store:"))
for i in range(n):
    product_id=input("enter the product id:")
    product_name=input("enter the product name:")
    product_price=int(input("enter the product price:"))
    product_quantity=int(input("enter the product quantity:"))
    product_category=input("enter the product category:")
    product_manu_date=input("enter the product manufacture date:")
    product_exp_date=input("enter the product expiryy date:")
    data=record
    if(product_id in data):
        record[product_id]={'Product_name': product_name,'Price': product_price,'Quantity': data[product_id]['Quantity']+product_quantity,'Category':product_category,'Manufacturing_date': product_manu_date , 'Expiry_date':  product_exp_date}
    else:
        record[product_id]={'Product_name': product_name,'Price': product_price,'Quantity': product_quantity,'Category':product_category,'Manufacturing_date': product_manu_date , 'Expiry_date':  product_exp_date}
# Out:
# enter number of product details you want to store:2
# enter the product id:1041
# enter the product name:Natraj
# enter the product price:20
# enter the product quantity:200
# enter the product category:Pen
# enter the product manufacture date:12-1-2021
# enter the product expiryy date:12-06-2021
# enter the product id:1042
# enter the product name:Cello
# enter the product price:30
# enter the product quantity:200
# enter the product category:Pen
# enter the product manufacture date:12-03-2021
# enter the product expiryy date:12-04-2021

# %%
updated_recorded_data=json.dumps(record)
updated_recorded_data
# Out:
# '{"1001": {"Product_name": "Maggie", "Price": 20, "Quantity": 198, "Category": "Noodles", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1002": {"Product_name": "Top Ramen", "Price": 70, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "14-03-21", "Expiry_date": "14-06-21"}, "1003": {"Product_name": "Soorya Noodles", "Price": 100, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "11-02-21", "Expiry_date": "11-05-21"}, "1004": {"Product_name": "Anil Noodles", "Price": 20, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "04-02-21", "Expiry_date": "12-05-21"}, "1005": {"Product_name": "Soupy Noodles", "Price": 140, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "10-02-21", "Expiry_date": "10-05-21"}, "1006": {"Product_name": "Freedom oil", "Price": 120, "Quantity": 300, "Category": "Oil", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1007": {"Product_name": "Fortune oil", "Price": 150, "Quantity": 40
# ...

# %%
fd=open("updated_recorded_data.json","a")
fd.write(updated_recorded_data)
fd.close()

# %%
fd=open("updated_recorded_data.json","r")
text=fd.read()
fd.close()
text
# Out:
# '{"1001": {"Product_name": "Maggie", "Price": 20, "Quantity": 198, "Category": "Noodles", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1002": {"Product_name": "Top Ramen", "Price": 70, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "14-03-21", "Expiry_date": "14-06-21"}, "1003": {"Product_name": "Soorya Noodles", "Price": 100, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "11-02-21", "Expiry_date": "11-05-21"}, "1004": {"Product_name": "Anil Noodles", "Price": 20, "Quantity": 300, "Category": "Noodles", "Manufacturing_date": "04-02-21", "Expiry_date": "12-05-21"}, "1005": {"Product_name": "Soupy Noodles", "Price": 140, "Quantity": 350, "Category": "Noodles", "Manufacturing_date": "10-02-21", "Expiry_date": "10-05-21"}, "1006": {"Product_name": "Freedom oil", "Price": 120, "Quantity": 300, "Category": "Oil", "Manufacturing_date": "12-02-21", "Expiry_date": "12-05-21"}, "1007": {"Product_name": "Fortune oil", "Price": 150, "Quantity": 40
# ...

# %%
fs=open("sales_data.json","r")
sales_details=fs.read()
fs.close()
sales_details
# Out:
# '{"1": {"customer_name": "Pratheeksha", "customer_address": "Karnataka", "Details": {"Sprite": 2}, "transaction_time": "Mon Sep  6 21:16:32 2021"}}{"2": {"customer_name": "Prabha", "customer_address": "Karnataka", "Details": {"Maggie": 2}, "transaction_time": "Mon Sep  6 21:17:27 2021"}}'
